# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# as well as an

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
    sat = pd.read_csv('../data/sat_2017.csv')
    act = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
sat.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
#Code:
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 2.9+ KB

# %%
act.describe().T
# Out:
#          count       mean       std   min     25%    50%     75%   max
# English   52.0  20.919231  2.332132  16.3  19.000  20.55  23.300  25.5
# Math      52.0  21.173077  1.963602  18.0  19.400  20.90  23.100  25.3
# Reading   52.0  22.001923  2.048672  18.1  20.475  21.70  24.125  26.0
# Science   52.0  21.040385  3.151113   2.3  19.900  21.15  22.525  24.9

# %%
sat.describe().T
# Out:
#                                         count         mean        std    min  \
# sat participation                        51.0    39.803922  35.276632    2.0
# sat evidence-based reading and writing   51.0   569.117647  45.666901  482.0
# sat math                                 51.0   547.627451  84.909119   52.0
# sat total                                51.0  1126.098039  92.494812  950.0
#
#                                            25%     50%     75%     max
# sat participation                          4.0    38.0    66.0   100.0
# sat evidence-based reading and writing   533.5   559.0   613.0   644.0
# sat math                                 522.0   548.0   599.0   651.0
# sat total                               1055.5  1107.0  1212.0  1295.0

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
# SAT:
# The SAT data seems, for the most part, completely filled in. There are 51 entries in all sections. All are integers or floats except for participation. The average value for Reading and Writing is 569, for math is 547, and the total average value is 1126. The top 5 best performing states are D.C, Delaware, Idaho, Michigan, and Maine. The lowest 5 performing states are Kansas, Missouri, Iowa, Wisconsin, and Minnesota.
#
# ACT:
# There appear to be no missing values for the ACT data. There are 52 counts, because the ACT data includes a National count. This will be dropped later on. Th average value for english is 20.9, for math is 21.2, for reading is 22.0, science is 21, and the mean composite score is 21.5. The top 5 performing states are Nevada, Mississippi, South Carolina, Hawaii, and North Carolina.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer:
#
# The data appears to be complete. Both data sets say they are non-null. They all have the same number of entries for each index.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer: the ACT data has one more observation than the SAT data. Additionally, the ACT data has a "national" column
#
#
# The minimum possible value for the SAT (total) is: 400
# the maximum possible value for the SAT (total) is: 1600
# The minumum and maxiumu value for Math: 200-800
# The minimum and maximum value for Evidence-Based Reading and Writing: 200-800
#
# The minimum possible value for the ACT is: 1
# the maximum possible score for the ACT is: 36
# The minimum and maximum score for the english section: 0-75
# the minimum and maxium value for the math section: 0-60
# the minumum and maximum value for reading: 0-40
# the minimum and maximum value for science: 0-40

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
sat.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
# participation in both the SAT and ACT are objects.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
act.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
str_to_int = lambda x:float(x.replace("%",""))

# %%
#using .apply method to convert ACT participation object to float
act['Participation'] = act['Participation'].apply(str_to_int)

# %%
#new ACT participation as float 
act.head()
# Out:
#       State  Participation  English  Math  Reading  Science Composite
# 0  National           60.0     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100.0     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65.0     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62.0     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100.0     18.9  19.0     19.7     19.5      19.4

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
##using .apply method to convert SAT participation object to float
sat['Participation'] = sat['Participation'].apply(str_to_int)

# %%
#new SAT participation as float
sat.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5.0                                 593   572   1165
# 1      Alaska           38.0                                 547   533   1080
# 2     Arizona           30.0                                 563   553   1116
# 3    Arkansas            3.0                                 614   594   1208
# 4  California           53.0                                 531   524   1055

# %%
act.head()
# Out:
#       State  Participation  English  Math  Reading  Science Composite
# 0  National           60.0     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100.0     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65.0     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62.0     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100.0     18.9  19.0     19.7     19.5      19.4

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#Wyoming composite is 20.2x not 20.2
act.iloc[51, 6] = float(20.2)

act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null float64
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(5), object(2)
# memory usage: 2.9+ KB

# %%
#code to convert ACT composite score from object to float 
act['Composite'] = act.Composite.astype(float) 
act['Composite']
act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null float64
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code to show data types in SAT
sat.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
#code to show data types in ACT
act.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#renaming SAT
sat_2 = {"State": "State",
                             "Participation": "sat participation", 
                             "Evidence-Based Reading and Writing" : "sat evidence-based reading and writing", 
                             "Math": "sat math", 
                             "Total" : "sat total", 
                             }
sat.rename(columns = sat_2, inplace = True)

# %%
sat.head()
# Out:
#         State  sat participation  sat evidence-based reading and writing  \
# 0     Alabama                5.0                                     593
# 1      Alaska               38.0                                     547
# 2     Arizona               30.0                                     563
# 3    Arkansas                3.0                                     614
# 4  California               53.0                                     531
#
#    sat math  sat total
# 0       572       1165
# 1       533       1080
# 2       553       1116
# 3       594       1208
# 4       524       1055

# %%
act.head()
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National           60.0     20.3  20.7     21.4     21.0       21.0
# 1   Alabama          100.0     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           65.0     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           62.0     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas          100.0     18.9  19.0     19.7     19.5       19.4

# %%
act_2 = {"State": "State", 
                              "Participation": "act participation", 
                              "English": "act english", 
                              "Math": "act math", 
                              "Reading": "act reading", 
                              "Science": "act science", 
                              "Composite": "act composite",  
                              "Total": "act total", 
                              }

act.rename(columns = act_2, inplace = True)

# %%
act.head()
# Out:
#       State  act participation  act english  act math  act reading  \
# 0  National               60.0         20.3      20.7         21.4
# 1   Alabama              100.0         18.9      18.4         19.7
# 2    Alaska               65.0         18.7      19.8         20.4
# 3   Arizona               62.0         18.6      19.8         20.1
# 4  Arkansas              100.0         18.9      19.0         19.7
#
#    act science  act composite
# 0         21.0           21.0
# 1         19.4           19.2
# 2         19.9           19.8
# 3         19.8           19.7
# 4         19.5           19.4

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Columns|Type |Dataset|Description|
# |------|---|-------|----|
# |state|object|ACT|State in which the ACT was taken|
# |act paticipation|object|ACT|participation rate|
# |act english|float|ACT|ACT english score|
# |act math|float|ACT|ACT math score|
# |act reading|float|ACT|ACT reading score|
# |act science|float|ACT|ACT science sore|
# |act composite|object|ACT|Composite ACT score|

# %% [markdown]
# |Columns|Type |Dataset|Description|
# |------|---|-------|----|
# |state|object|SAT|state in which the SAT was taken|
# |sat participation|float|SAT| participation rate of the SAT|
# |sat evidence-based reading and writing|float| SAT| scores of SAT Evidence Based Reading and Writing|
# |sat math|float|SAT|SAT math scores|
# |sat total|float|SAT|SAT total scores|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %% [markdown]
# the row called 'National' should be dropped from the dataframe because this row does not exist in the SAT data.

# %%
#code

act.drop([0], axis = 0, inplace = True)
act.head()
# Out:
#         State  act participation  act english  act math  act reading  \
# 1     Alabama              100.0         18.9      18.4         19.7
# 2      Alaska               65.0         18.7      19.8         20.4
# 3     Arizona               62.0         18.6      19.8         20.1
# 4    Arkansas              100.0         18.9      19.0         19.7
# 5  California               31.0         22.5      22.7         23.1
#
#    act science  act composite
# 1         19.4           19.2
# 2         19.9           19.8
# 3         19.8           19.7
# 4         19.5           19.4
# 5         22.2           22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:

combined = pd.merge(sat, act, on='State')
combined.head()
# Out:
#         State  sat participation  sat evidence-based reading and writing  \
# 0     Alabama                5.0                                     593
# 1      Alaska               38.0                                     547
# 2     Arizona               30.0                                     563
# 3    Arkansas                3.0                                     614
# 4  California               53.0                                     531
#
#    sat math  sat total  act participation  act english  act math  act reading  \
# 0       572       1165              100.0         18.9      18.4         19.7
# 1       533       1080               65.0         18.7      19.8         20.4
# 2       553       1116               62.0         18.6      19.8         20.1
# 3       594       1208              100.0         18.9      19.0         19.7
# 4       524       1055               31.0         22.5      22.7         23.1
#
#    act science  act composite
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code

combined.to_csv("../data/combined_2017.csv")

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
#import both datasets
sat_2018 = pd.read_csv('../data/2018_sat.csv')
act_2018 =pd.read_csv('../data/2018_act.csv')

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %% [markdown]
# So, in both datasets participation is an object. I will convert these to floats with a lambda function I created for the 2017 data.

# %%
str_to_int = lambda x:float(x.replace("%",""))

# %%
act_2018['Participation'] = act_2018['Participation'].apply(str_to_int)

# %%
sat_2018['Participation'] = sat_2018['Participation'].apply(str_to_int)

# %%
#We can now see for both datasets, participation has become a float rather than an object
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
# State            52 non-null object
# Participation    52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# the act_218 data has 'National', next I'm going to drop that row.

# %%
#act_2018.drop([51], axis = 0, inplace = True)
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
# State            52 non-null object
# Participation    52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# time to rename some columns!

# %%
act_2018_2 = {"State": "State", 
                              "Participation": "act_18 participation", 
                              "Composite": "act_18 composite"
             }

act_2018.rename(columns = act_2018_2, inplace = True)
act_2018.head()
# Out:
#         State  act_18 participation  act_18 composite
# 0     Alabama                 100.0              19.1
# 1      Alaska                  33.0              20.8
# 2     Arizona                  66.0              19.2
# 3    Arkansas                 100.0              19.4
# 4  California                  27.0              22.7

# %%
sat_2018_2 = {"State": "State", 
                              "Participation": "sat_18 participation", 
                              "Evidence-Based Reading and Writing": "sat_2018 evidence-based reading and writing",
                              "Math": "sat_2018 math",
                              "Total": "sat_2018 total",
                              "Composite": "act_18 composite"
             }
sat_2018.rename(columns = sat_2018_2, inplace = True)
sat_2018.head()
# Out:
#         State  sat_18 participation  \
# 0     Alabama                   6.0
# 1      Alaska                  43.0
# 2     Arizona                  29.0
# 3    Arkansas                   5.0
# 4  California                  60.0
#
#    sat_2018 evidence-based reading and writing  sat_2018 math  sat_2018 total
# 0                                          595            571            1166
# 1                                          562            544            1106
# 2                                          577            572            1149
# 3                                          592            576            1169
# 4                                          540            536            1076

# %% [markdown]
# Now, we combine both 2018 data frames!

# %%
combined_2018 = pd.merge(sat_2018, act_2018, on='State')
combined_2018.head()
# Out:
#         State  sat_18 participation  \
# 0     Alabama                   6.0
# 1      Alaska                  43.0
# 2     Arizona                  29.0
# 3    Arkansas                   5.0
# 4  California                  60.0
#
#    sat_2018 evidence-based reading and writing  sat_2018 math  sat_2018 total  \
# 0                                          595            571            1166
# 1                                          562            544            1106
# 2                                          577            572            1149
# 3                                          592            576            1169
# 4                                          540            536            1076
#
#    act_18 participation  act_18 composite
# 0                 100.0              19.1
# 1                  33.0              20.8
# 2                  66.0              19.2
# 3                 100.0              19.4
# 4                  27.0              22.7

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
final = pd.merge(combined, combined_2018, on='State')

final.to_csv("../data/final.csv")

# %%
#I changed the outliers to its proper data.
final.loc[final[final["State"] == "Maryland"].index, "sat math"] = 524
final.loc[final[final["State"] == "Maryland"].index, "act science"] = 23.2

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
final.describe().T
# Out:
#                                              count         mean        std  \
# sat participation                             48.0    40.020833  34.545985
# sat evidence-based reading and writing        48.0   570.395833  43.969399
# sat math                                      48.0   557.958333  46.128847
# sat total                                     48.0  1129.000000  89.521185
# act participation                             48.0    64.500000  31.992020
# act english                                   48.0    20.966667   2.313359
# act math                                      48.0    21.247917   1.933247
# act reading                                   48.0    22.060417   2.017238
# act science                                   48.0    21.502083   1.704124
# act composite                                 48.0    21.568750   1.977765
# sat_18 participation                          48.0    46.458333  36.959413
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
import math
import numpy as np

def std_dev(df, column_name):
    num = len(df[column_name])
    mean = sum(df[column_name])/num
    difference = [x - mean for x in df[column_name]]
    sq = [d ** 2 for d in difference]
    sd = sum(sq)
    
    return np.sqrt(sd/num)

# %%
final.head()
# Out:
#         State  sat participation  sat evidence-based reading and writing  \
# 0     Alabama                5.0                                     593
# 1      Alaska               38.0                                     547
# 2     Arizona               30.0                                     563
# 3    Arkansas                3.0                                     614
# 4  California               53.0                                     531
#
#    sat math  sat total  act participation  act english  act math  act reading  \
# 0       572       1165              100.0         18.9      18.4         19.7
# 1       533       1080               65.0         18.7      19.8         20.4
# 2       553       1116               62.0         18.6      19.8         20.1
# 3       594       1208              100.0         18.9      19.0         19.7
# 4       524       1055               31.0         22.5      22.7         23.1
#
#    act science  act composite  sat_18 participation  \
# ...

# %%
np.std(final['sat participation'])
# Out:
# 34.18423709799916

# %%
std_dev(final, 'sat participation')
# Out:
# 34.184237097999166

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
sd = {column:std_dev(df=final,column_name=column) for column in final.columns[1:]}
sd
# Out:
# {'sat participation': 34.184237097999166,
#  'sat evidence-based reading and writing': 43.50897397057556,
#  'sat math': 45.645809561837716,
#  'sat total': 88.58376450192966,
#  'act participation': 31.657016073323565,
#  'act english': 2.28913496519731,
#  'act math': 1.9130026118789165,
#  'act reading': 1.9961149331611365,
#  'act science': 1.686279136557435,
#  'act composite': 1.957055212344983,
#  'sat_18 participation': 36.57239301106171,
#  'sat_2018 evidence-based reading and writing': 46.425268502783645,
#  'sat_2018 math': 46.659667443866574,
#  'sat_2018 total': 91.95061136586074,
#  'act_18 participation': 33.561821067000125,
#  'act_18 composite': 2.067187434387334}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer: These calculated numbers are very close to each other.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Highest SAT 17 value = Minnesota, Wisconsin, Iowa, Missouri, Kansas
#Lowest SAT 17 value = Florida, Texas, Maine,Idaho, Michigan

final.sort_values('sat total', ascending = False).head() #or.tail()
# Out:
#         State  sat participation  sat evidence-based reading and writing  \
# 22  Minnesota                3.0                                     644
# 46  Wisconsin                3.0                                     642
# 14       Iowa                2.0                                     641
# 23   Missouri                3.0                                     640
# 15     Kansas                4.0                                     632
#
#     sat math  sat total  act participation  act english  act math  \
# 22       651       1295              100.0         20.4      21.5
# 46       649       1291              100.0         19.7      20.4
# 14       635       1275               67.0         21.2      21.3
# 23       631       1271              100.0         19.8      19.9
# 15       628       1260               73.0         21.1      21.3
#
#     act reading  act science  act composite  sat_18 participation  \
# ...

# %%
#Highest SAT 18 value= Minnesota, Wisconsin, ND, Iowa, Kansas, Missouri
#Lowest SAT 18 value = Utah, Hawaii, Idaho, WV, Delaware

final.sort_values('sat_2018 total', ascending = False).head() #or.tail()
# Out:
#            State  sat participation  sat evidence-based reading and writing  \
# 22     Minnesota                3.0                                     644
# 46     Wisconsin                3.0                                     642
# 32  North Dakota                2.0                                     635
# 14          Iowa                2.0                                     641
# 15        Kansas                4.0                                     632
#
#     sat math  sat total  act participation  act english  act math  \
# 22       651       1295              100.0         20.4      21.5
# 46       649       1291              100.0         19.7      20.4
# 32       621       1256               98.0         19.0      20.4
# 14       635       1275               67.0         21.2      21.3
# 15       628       1260               73.0         21.1      21.3
#
#     act reading  act science  act composite  sat_18 participation  \
# ...

# %%
#Do any states show have >50% participation on both tests either year?

partip_2017 = (final['sat participation'] > 50) & (final['act participation'] > 50)
final[partip_2017]
# Out:
#       State  sat participation  sat evidence-based reading and writing  \
# 8   Florida               83.0                                     520
# 9   Georgia               61.0                                     535
# 10   Hawaii               55.0                                     544
#
#     sat math  sat total  act participation  act english  act math  \
# 8        497       1017               73.0         19.0      19.4
# 9        515       1050               55.0         21.0      20.9
# 10       541       1085               90.0         17.8      19.2
#
#     act reading  act science  act composite  sat_18 participation  \
# 8          21.0         19.4           19.8                  56.0
# 9          22.0         21.3           21.4                  70.0
# 10         19.2         19.3           19.0                  56.0
#
#     sat_2018 evidence-based reading and writing  sat_2018 math  \
# 8                                           550            549
# ...

# %%
#FL, GA, and HI remain the same. Participation > 50% also now inclused NC and SC
partip_2018 = (final['sat_18 participation'] > 50) & (final['act_18 participation'] > 50)
final[partip_2018]
# Out:
#              State  sat participation  sat evidence-based reading and writing  \
# 8          Florida               83.0                                     520
# 9          Georgia               61.0                                     535
# 10          Hawaii               55.0                                     544
# 31  North Carolina               49.0                                     546
# 37  South Carolina               50.0                                     543
#
#     sat math  sat total  act participation  act english  act math  \
# 8        497       1017               73.0         19.0      19.4
# 9        515       1050               55.0         21.0      20.9
# 10       541       1085               90.0         17.8      19.2
# 31       535       1081              100.0         17.8      19.3
# 37       521       1064              100.0         17.5      18.6
#
#     act reading  act science  act composite  sat_18 participation  \
# ...

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
plt.figure(figsize=(15,15))
sns.heatmap(final.corr(), cmap = 'viridis', annot = True);
plt.title('Correlations between SAT and ACT scores and Participation');

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels):
    nrows = int(np.ceil(len(list_of_columns)/2))                   # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (16, 12)) # You'll want to specify your figsize
    ax = ax.ravel()                              # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns):    # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column])       # feel free to add more settings
        ax[i].set_title(list_of_titles[i])                # Set titles, labels, etc here for each subplot
        ax[i].set_xlabel(list_of_xlabels[i])
        ax[i].set_ylabel(list_of_ylabels[i])

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
#HIST Participation SAT and ACT 2017 and 2018

subplot_histograms(final,
                   ['sat participation',
                    'act participation', 
                    'sat_18 participation', 
                    'act_18 participation'], 
                   ['Participation Rates SAT 2017',
                    'Participation Rates ACT 2017', 
                    'Participation Rates SAT 2018',
                    'Participation Rates ACT 2018'],
                   ['2017 SAT', 
                    '2017 ACT', 
                    '2018 SAT', 
                    '2018 ACT'],
                   ['rate of participation',
                    'rate of participation',
                    'rate of participation',
                    'rate of participation'])

# %%
#HIST Math scores for SAT & ACT 2017
subplot_histograms(final, ['sat math',
                           'act math'], 
                   ['SAT Math Scores 2017',
                    'ACT Math Scores 2017'],
                   ['Scores', 'Scores'],
                  ['SAT Math Scores', 
                   'ACT Math Scores'])

# %%
#HIST Reading/verbal scores for SAT & ACT 2017 and 2018
subplot_histograms(final, ['sat evidence-based reading and writing',
                           'act english'], 
                   ['SAT Reading & Writing',
                    'ACT English'],
                   ['Scores', 'Scores'],
                  ['Rate', 'Rate'])

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
#scatterplt Math scores for SAT & ACT 2017
plt.figure(figsize = (8,5))
plt.scatter(final['sat math'],final['act math'], color = 'indigo')
plt.xlabel('SAT Math Scores')
plt.ylabel('ACT Math Scores')
plt.title('Math scores for SAT and ACT in 2017');

# %%
#scatter SAT vs. ACT verbal/reading scores for 2017
plt.figure(figsize = (8,5))
plt.scatter(final['sat evidence-based reading and writing'], final['act english'], color='indigo')
plt.xlabel('SAT Verbal/Reading Scores')
plt.ylabel('ACT Verbal/Reading Scores')
plt.title('Verbal/Reasoning scores for SAT and ACT in 2017');

# %%
#scatter SAT vs. ACT total/composite scores for 2017
plt.figure(figsize = (8,5))
plt.scatter(final['sat total'], final['act composite'], color='indigo')
plt.xlabel('SAT Total')
plt.ylabel('ACT Composite')
plt.title('Total scores for SAT and ACT in 2017');

# %%
#scatter Total scores for SAT 2017 vs. 2018
plt.figure(figsize = (8,5))
plt.scatter(final['sat total'], final['sat_2018 total'], color='indigo')
plt.xlabel('2017 scores')
plt.ylabel('2018 scores')
plt.title('Comparison of Total scores for SAT in 2017 and 2018');

# %%
#scatter Composite scores for ACT 2017 vs. 2018
plt.figure(figsize = (8,5))
plt.scatter(final['act composite'], final['act_18 composite'], color='indigo')
plt.xlabel('ACT 2017 Total Scores')
plt.ylabel('ACT 2018 Total Scores')
plt.title('Compared Total scores for ACT in 2017 and 2018');

#There is a positive correlation between ACT 2017 and 2018 scores.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
final.head()
# Out:
#         State  sat participation  sat evidence-based reading and writing  \
# 0     Alabama                5.0                                     593
# 1      Alaska               38.0                                     547
# 2     Arizona               30.0                                     563
# 3    Arkansas                3.0                                     614
# 4  California               53.0                                     531
#
#    sat math  sat total  act participation  act english  act math  act reading  \
# 0       572       1165              100.0         18.9      18.4         19.7
# 1       533       1080               65.0         18.7      19.8         20.4
# 2       553       1116               62.0         18.6      19.8         20.1
# 3       594       1208              100.0         18.9      19.0         19.7
# 4       524       1055               31.0         22.5      22.7         23.1
#
#    act science  act composite  sat_18 participation  \
# ...

# %%
import seaborn as sns
ax = sns.boxplot (data = [final["sat total"], final["sat_2018 total"]])
ax.set_title("Sat 2017 and 2018 Total")
ax.set_xlabel("SAT")
ax.set_ylabel("SAT scores")
ax.set(xticklabels=['sat total', 'sat_2018 total']);

# %%
#comparing SAT participation with ACT participation
plt.figure(figsize = (8, 8))
ax = sns.boxplot(data = [final["sat participation"], 
                                final["act participation"], 
                                final["sat_18 participation"], 
                                final["act_18 participation"]]);
ax.set_title("SAT and ACT Participation in 2017 and 2018")
ax.set_xlabel("SAT and ACT 2017 and 2018")
ax.set_ylabel("Participation Rate")
ax.set(xticklabels=['sat participation', 'act participation', 'sat_18 participation', 'act_18 participation']);

# %%
#comparing ACT composite scores in 2017 and 2018
ax = sns.boxplot(data = [final['act composite'], final['act_18 composite']])
ax.set_title("ACT Composite Scores 2017 and 2018")
ax.set_xlabel("2017 and 2018")
ax.set_ylabel("Composite Scores")
ax.set(xticklabels=['act composite', 'act_18 composite']);

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#Participation in ACT is inversely related with SAT Participation 
plt.figure(figsize = (5, 10))
plt.barh(y = final['State'], width = final['act_18 participation'])
plt.xlabel('ACT Participation')
plt.ylabel('State')
plt.title('Participation by State 2018');

# %%
plt.figure(figsize = (5, 10))
plt.barh(y = final['State'], width = final['sat participation'])
plt.xlabel('SAT Participation')
plt.ylabel('State')
plt.title('Participation by State 2017');

# %%
final.sort_values(by='sat_18 participation', ascending = False).head()
# Out:
#           State  sat participation  sat evidence-based reading and writing  \
# 5      Colorado               11.0                                     606
# 6   Connecticut              100.0                                     530
# 7      Delaware              100.0                                     503
# 21     Michigan              100.0                                     509
# 11        Idaho               93.0                                     513
#
#     sat math  sat total  act participation  act english  act math  \
# 5        595       1201              100.0         20.1      20.3
# 6        512       1041               31.0         25.5      24.6
# 7        492        996               18.0         24.1      23.4
# 21       495       1005               29.0         24.1      23.7
# 11       493       1005               38.0         21.9      21.8
#
#     act reading  act science  act composite  sat_18 participation  \
# ...

# %%
final.sort_values(by = 'act_18 participation', ascending = False).head(20)
# Out:
#              State  sat participation  sat evidence-based reading and writing  \
# 0          Alabama                5.0                                     593
# 16        Kentucky                4.0                                     631
# 46       Wisconsin                3.0                                     642
# 41            Utah                3.0                                     624
# 39       Tennessee                5.0                                     623
# 37  South Carolina               50.0                                     543
# 33            Ohio               12.0                                     578
# 31  North Carolina               49.0                                     546
# 26          Nevada               26.0                                     563
# 25        Nebraska                3.0                                     629
# 23        Missouri                3.0                                     640
# ...

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %%
final.describe().T
# Out:
#                                              count         mean        std  \
# sat participation                             48.0    40.020833  34.545985
# sat evidence-based reading and writing        48.0   570.395833  43.969399
# sat math                                      48.0   557.958333  46.128847
# sat total                                     48.0  1129.000000  89.521185
# act participation                             48.0    64.500000  31.992020
# act english                                   48.0    20.966667   2.313359
# act math                                      48.0    21.247917   1.933247
# act reading                                   48.0    22.060417   2.017238
# act science                                   48.0    21.502083   1.704124
# act composite                                 48.0    21.568750   1.977765
# sat_18 participation                          48.0    46.458333  36.959413
# ...

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:
#
# The Average ACT participation rate in 2017 was 64%, and in 2018 it declined to 60.7%.
#
#
# ACT participation rates between 2017 and 2018 have consistently been higher than SAT participation rates. However, SAT participation did increase in 2018. In 2017, the mean SAT rates was 40%. By 2018, the mean SAT rates increased to around around 47% in 2018. By contrast, ACT mean participation rates were 64% in 2017, and it declined to 60.7% in 2018
#
# Top highest participating states in 2017 for SAT: Michigan, Connecticut, Delaware, New Hampshire, and Maine
# the lowest participating states in 2017 for ACT: PA, Rhode Island, New Hampshire, Delaware and Maine
#
# The lowest participating states in 2017 for SAT: Arkansas, Wisconsin, Wyoming, North Dakota, and Iowa
# Top highest participating states in 2017 ACT: Alabama, Kentucky, Wisconsin, Utah, and Tennesee
#
# Top highest participating states in 2018 SAT: Connecticult, Colorado, Delaware, Michigan, and Idaho.
# The lowest participating states in 2018 for ACT: PA, Delaware, New Hampshire, RI, and Maine.
#
# The lowest participating states in 2018 for SAT: SD, Iowa, Wisconsin, Wyoming, and North Dakota.
# Top highest participating states in 2018 ACT remained exactly the same from 2017.
#
# In general, the relationship between highest and lowest participating states for ACT and SAT are inversely related. For states where SAT participation is high, ACT participation is low.
#
# For a more concrete example, when I filter final.csv to sort through the data by highest SAT test scores:
#
# the States with the highest SAT scores in 2017 had the lowest SAT participation rate, and highest ACT Participation Rates:
#
# MN - 1295 - 3% sat part - 100% act part
# WI -  1291 - 3% sat part  - 100% act part
# Iowa - 1275 - 2% sat part  - 67% act
# MO - 1271 -  3% sat part  - 100% act part
# KS - 1260 - 4% sat part  - 73% act part
#
# The same for the inverse is true, and also the same occurs in 2018. High ACT participation, means seems to result in lower ACT scores, and higher scores for the SAT. If I had more time and data, I would like to explore this relationship further.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: We did not observe this trend.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data:
#
#
#
# From the histograms above, it appears that none of the plots followed a normal distribution.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer: It could be appropriate to compare specific ACT and SAT math scores. My initial concern was that even normalizing the data wouldn't mean that the scores would be equivalent to its respective test (i.e. normalizing the SAT math score might not equal the ACT math score). However, college board provides a conversion for each ACT score and its corresponding total SAT score. There is also a graph to show ACT math to SAT math and English + Reading. (https://collegereadiness.collegeboard.org/pdf/guide-2018-act-sat-concordance.pdf).
#
# Using that information, I believe it would be appropriate, as there is a source that provides the equivalent score for each.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# There are twelve states that offer the ACT,or some ACT suite test, for free. These states have among the highest rates of participation for those exams. Among those, I have identified 3 states that stood out to me that had low SAT participation rates, high schores, and high ACT participation rates.

# %% [markdown]
# #### North Dakota
# has a 2% participation rate, and total SAT 2018 scores as 1283. The ACT composite scores are 20.3 wtih a 98% participation rate.
#
# Even with free testing, the ACT scores are still relatively good. Although, the general trend is that states with high ACT participation rates tend to have lower scores for ACT, I thought because the ACT score is still fairly good, ND was an interesting state to look at.
#
# According to maggoosh (https://magoosh.com/hs/act/2017/states-provide-act-free/), North Dakota also has free testing for other ACT 'suite' options, perhaps attributing to higher ACT test scores

# %% [markdown]
# #### Kentucky
# 4% SAT participation rate, SAT score total 1248, act composite score is 20.2 and KY has a 100% ACT participation rate. Similar to North Dakota, in that KY has free ACT tests. North Dakota's SAT participation rate is very low, as well, and also with a very high SAT total score. This suggests, again, that there are a few people who have the resources to be able to take the SAT over the, likely more favorable, free ACT test.

# %% [markdown]
# #### Kansas
# Kansas is another state with a very low participation rate (of 4%), and a high SAT total score of 1265 in 2018. Compared to a 71% participation rate of ACT. From these three states, I gather that having a free test in a state makes it more likely that the participation rate for that state will be significantly higher. This makes sense because it removes a significant barrier - the cost of the ACT.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# States with high SAT participation, tend to see low SAT participation rates, and high ACT rates. As a trend, it seems that states with extremely high ACT rates have higher total SAT scores. This makes sense because less people are probably taking the SAT in free ACT states, and those who are are confident they will perform better on the SAT than the ACT. There are several states that offer the ACT for free, which increases participation for those tests significantly. This is shown while sorting for ACT participation rates, the states with the highest rates are also on the list of states that provide free ACT testing.
#
# Based on this information with ACT testing, it would make sense that if states could offer free SAT testing, participation rates for a state like Louisiana (which does offer free ACT testing), could increase participation rates, and also allow students who think they may perform better on the SAT, but cannot afford it, the chance to participate.
#
#
# From my research, there is a general consensus that making standardized tests more accessable make it easier for communities who normally wouldn't consider college, able to take it into account. From a blog about test prep, "there is some debate on using the ACT as a statewide test for all students because it becomes yet another standardized test that students are required to take. However, studies performed by ACT and other organizations point to some advantages of using the test in this way. The studies seem to indicate that the average scores on the test increase over time when the ACT becomes a statewide test. It can also be a factor in increasing enrollment in college. Students who might not otherwise have taken the test because they were not considering college as an option may end up enrolling in college, since after they take the test, they’ll know what colleges may accept them." (https://www.petersons.com/blog/the-act-test-as-a-standard-state-test/)
#
# This suggests that there are significant merrits to making the SAT free. It allows people who would not traditionally be able to afford college an opportunity to apply. When considering application fees, the cost of college, on top of the fees to take the test, this makes a considerable amount of sense for low income families.
#
# My biggest recommendation is to consider making the SAT free in order to make this opportunity available for students in general, and especially in states where the ACT is already free. This provides more choice for students who think they may perform better on the SAT rather than the ACT. Providing students with a choice of which test to take allows low income families the same benefits that families who can afford the regular price of these tests, thus creating an less barriers for an opportunity for to college acceptance.
